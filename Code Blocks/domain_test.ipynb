# %%
import bs4
import requests as req
from datetime import datetime
import json
import numpy as np
import pandas as pd

agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36"
headers = {'user-agent':agent}
property_listings = []
postcode_queries = []

def get_nextpage(page):
    try:
        link=page.find('div',{'class':'pagination__link-next-wrapper'}).find('a',href=True)['href']
        return 'https://www.realestate.com.au'+link
    except:
        return False
def to_date(solddate):
    date = solddate.lower().strip('sold on')
    date = datetime.strptime(date, '%d %b %Y')
    return date.date()
def prop_list_json(htmlpage):
    js=htmlpage.find('script',{'type':'application/ld+json'}).string
    js=json.loads(js)
    return js
def get_details(properties, js):
    for prop, j in zip(properties, js):
        add=j.get('address')
        address=add.get('streetAddress')
        postcode=add.get('postalCode')
        suburb = add.get('addressLocality')

        price = prop.find('span',{'class':'property-price'}).text
        price = price[1:].replace(',','')

        try:
            beds=int(prop.find('span',{'class':'general-features__icon general-features__beds'}).text)
        except: beds=None
        try:
            bath=int(prop.find('span',{'class':'general-features__icon general-features__baths'}).text)
        except: bath=None
        try:
            cars=int(prop.find('span',{'class':'general-features__icon general-features__cars'}).text)
        except: cars=None
        ptype = prop.find('span',{'class':'residential-card__property-type'}).text.lower()
        sold_date = prop.find('div',{'class':'residential-card__content'}).find_all('span')[-1].text
        sold_date = to_date(sold_date)
        property_listings.append([address,suburb,postcode,price,beds,bath,cars,ptype,sold_date])
    return

def scrape_page(url):
    res = req.get(url, headers=headers)
    webpage = bs4.BeautifulSoup(res.text, 'html')
    try:
        js=prop_list_json(webpage)
        properties = webpage.find_all('div',{'class':'residential-card__content-wrapper'})
        get_details(properties,js)
        return webpage
    except:
        print('no results')
def scrape_postcode(url):
    current_page = url
    while True:
        webpage= scrape_page(current_page)
        if (get_nextpage(webpage) == False):
            break
        else:
            current_page = get_nextpage(webpage)
    return 

f = open("postcodes.txt", "r")
lines = f.read().splitlines()
for l in lines:
    postcode = l.split('\t')[-1]
    query= 'https://www.realestate.com.au/sold/property-house-townhouse-villa-in-'+str(postcode)+'/list-1?includeSurrounding=false&misc=ex-no-sale-price&source=refinement'
    postcode_queries.append(query)
    
postcode_queries = list(set(postcode_queries))

i=1;
for ps in postcode_queries:
    scrape_postcode(ps)
    print('done postcode: ',i, 'of 225')
    i+=1

colnames=['address','suburb','postalCode','sellPrice','bed','bath','car','propType','Date']
data=pd.DataFrame(property_listings, columns=colnames)
data.to_csv('sydhouseprices.csv',index=False)
# Out:
# no results
# done postcode:  1 of 225
# no results
# done postcode:  2 of 225
# no results
# done postcode:  3 of 225
# no results
# done postcode:  4 of 225
# no results
# done postcode:  5 of 225
# no results
# done postcode:  6 of 225
# no results
# done postcode:  7 of 225
# no results
# done postcode:  8 of 225
# no results
# done postcode:  9 of 225
# no results
# done postcode:  10 of 225
# no results
# done postcode:  11 of 225
# no results
# done postcode:  12 of 225
# no results
# done postcode:  13 of 225
# no results
# done postcode:  14 of 225
# no results
# done postcode:  15 of 225
# no results
# done postcode:  16 of 225
# no results
# done postcode:  17 of 225
# no results
# done postcode:  18 of 225
# no results
# done postcode:  19 of 225
# no results
# done postcode:  20 of 225
# no results
# done postcode:  21 of 225
# no results
# done postcode:  22 of 225
# no results
# done postcode:  23 of 225
# no results
# done postcode:  24 of 225
# no results
# done postcode:  25 of 225
# no results
# done postcode:  26 of 225
# no results
# done postcode:  27 of 225
# no results
# done postcode:  28 of 225
# no results
# done postcode:  29 of 225
# no results
# done postcode:  30 of 225
# no results
# done postcode:  31 of 225
# no results
# done postcode:  32 of 225
# no results
# done postcode:  33 of 225
# no results
# done postcode:  34 of 225
# no results
# done postcode:  35 of 225
# no results
# done postcode:  36 of 225
# no results
# done postcode:  37 of 225
# no results
# done postcode:  38 of 225
# no results
# done postcode:  39 of 225
# no results
# done postcode:  40 of 225
# no results
# done postcode:  41 of 225
# no results
# done postcode:  42 of 225
# no results
# done postcode:  43 of 225
# no results
# done postcode:  44 of 225
# no results
# done postcode:  45 of 225
# no results
# done postcode:  46 of 225
# no results
# done postcode:  47 of 225
# no results
# done postcode:  48 of 225
# no results
# done postcode:  49 of 225
# no results
# done postcode:  50 of 225
# no results
# done postcode:  51 of 225
# no results
# done postcode:  52 of 225
# no results
# done postcode:  53 of 225
# no results
# done postcode:  54 of 225
# no results
# done postcode:  55 of 225
# no results
# done postcode:  56 of 225
# no results
# done postcode:  57 of 225
# no results
# done postcode:  58 of 225
# no results
# done postcode:  59 of 225
# no results
# done postcode:  60 of 225
# no results
# done postcode:  61 of 225
# no results
# done postcode:  62 of 225
# no results
# done postcode:  63 of 225
# no results
# done postcode:  64 of 225
# no results
# done postcode:  65 of 225
# no results
# done postcode:  66 of 225
# no results
# done postcode:  67 of 225
# no results
# done postcode:  68 of 225
# no results
# done postcode:  69 of 225
# no results
# done postcode:  70 of 225
# no results
# done postcode:  71 of 225
# no results
# done postcode:  72 of 225
# no results
# done postcode:  73 of 225
# no results
# done postcode:  74 of 225
# no results
# done postcode:  75 of 225
# no results
# done postcode:  76 of 225
# no results
# done postcode:  77 of 225
# no results
# done postcode:  78 of 225
# no results
# done postcode:  79 of 225
# no results
# done postcode:  80 of 225
# no results
# done postcode:  81 of 225
# no results
# done postcode:  82 of 225
# no results
# done postcode:  83 of 225
# no results
# done postcode:  84 of 225
# no results
# done postcode:  85 of 225
# no results
# done postcode:  86 of 225
# no results
# done postcode:  87 of 225
# no results
# done postcode:  88 of 225
# no results
# done postcode:  89 of 225
# no results
# done postcode:  90 of 225
# no results
# done postcode:  91 of 225
# no results
# done postcode:  92 of 225
# no results
# done postcode:  93 of 225
# no results
# done postcode:  94 of 225
# no results
# done postcode:  95 of 225
# no results
# done postcode:  96 of 225
# no results
# done postcode:  97 of 225
# no results
# done postcode:  98 of 225
# no results
# done postcode:  99 of 225
# no results
# done postcode:  100 of 225
# no results
# done postcode:  101 of 225
# no results
# done postcode:  102 of 225
# no results
# done postcode:  103 of 225
# no results
# done postcode:  104 of 225
# no results
# done postcode:  105 of 225
# no results
# done postcode:  106 of 225
# no results
# done postcode:  107 of 225
# no results
# done postcode:  108 of 225
# no results
# done postcode:  109 of 225
# no results
# done postcode:  110 of 225
# no results
# done postcode:  111 of 225
# no results
# done postcode:  112 of 225
# no results
# done postcode:  113 of 225
# no results
# done postcode:  114 of 225
# no results
# done postcode:  115 of 225
# no results
# done postcode:  116 of 225
# no results
# done postcode:  117 of 225
# no results
# done postcode:  118 of 225
# no results
# done postcode:  119 of 225
# no results
# done postcode:  120 of 225
# no results
# done postcode:  121 of 225
# no results
# done postcode:  122 of 225
# no results
# done postcode:  123 of 225
# no results
# done postcode:  124 of 225
# no results
# done postcode:  125 of 225
# no results
# done postcode:  126 of 225
# no results
# done postcode:  127 of 225
# no results
# done postcode:  128 of 225
# no results
# done postcode:  129 of 225
# no results
# done postcode:  130 of 225
# no results
# done postcode:  131 of 225
# no results
# done postcode:  132 of 225
# no results
# done postcode:  133 of 225
# no results
# done postcode:  134 of 225
# no results
# done postcode:  135 of 225
# no results
# done postcode:  136 of 225
# no results
# done postcode:  137 of 225
# no results
# done postcode:  138 of 225
# no results
# done postcode:  139 of 225
# no results
# done postcode:  140 of 225
# no results
# done postcode:  141 of 225
# no results
# done postcode:  142 of 225
# no results
# done postcode:  143 of 225
# no results
# done postcode:  144 of 225
# no results
# done postcode:  145 of 225
# no results
# done postcode:  146 of 225
# no results
# done postcode:  147 of 225
# no results
# done postcode:  148 of 225
# no results
# done postcode:  149 of 225
# no results
# done postcode:  150 of 225
# no results
# done postcode:  151 of 225
# no results
# done postcode:  152 of 225
# no results
# done postcode:  153 of 225
# no results
# done postcode:  154 of 225
# no results
# done postcode:  155 of 225
# no results
# done postcode:  156 of 225
# no results
# done postcode:  157 of 225
# no results
# done postcode:  158 of 225
# no results
# done postcode:  159 of 225
# no results
# done postcode:  160 of 225
# no results
# done postcode:  161 of 225
# no results
# done postcode:  162 of 225
# no results
# done postcode:  163 of 225
# no results
# done postcode:  164 of 225
# no results
# done postcode:  165 of 225
# no results
# done postcode:  166 of 225
# no results
# done postcode:  167 of 225
# no results
# done postcode:  168 of 225
# no results
# done postcode:  169 of 225
# no results
# done postcode:  170 of 225
# no results
# done postcode:  171 of 225
# no results
# done postcode:  172 of 225
# no results
# done postcode:  173 of 225
# no results
# done postcode:  174 of 225
# no results
# done postcode:  175 of 225
# no results
# done postcode:  176 of 225
# no results
# done postcode:  177 of 225
# no results
# done postcode:  178 of 225
# no results
# done postcode:  179 of 225
# no results
# done postcode:  180 of 225
# no results
# done postcode:  181 of 225
# no results
# done postcode:  182 of 225
# no results
# done postcode:  183 of 225
# no results
# done postcode:  184 of 225
# no results
# done postcode:  185 of 225
# no results
# done postcode:  186 of 225
# no results
# done postcode:  187 of 225
# no results
# done postcode:  188 of 225
# no results
# done postcode:  189 of 225
# no results
# done postcode:  190 of 225
# no results
# done postcode:  191 of 225
# no results
# done postcode:  192 of 225
# no results
# done postcode:  193 of 225
# no results
# done postcode:  194 of 225
# no results
# done postcode:  195 of 225
# no results
# done postcode:  196 of 225
# no results
# done postcode:  197 of 225
# no results
# done postcode:  198 of 225
# no results
# done postcode:  199 of 225
# no results
# done postcode:  200 of 225
# no results
# done postcode:  201 of 225
# no results
# done postcode:  202 of 225
# no results
# done postcode:  203 of 225
# no results
# done postcode:  204 of 225
# no results
# done postcode:  205 of 225
# no results
# done postcode:  206 of 225
# no results
# done postcode:  207 of 225
# no results
# done postcode:  208 of 225
# no results
# done postcode:  209 of 225
# no results
# done postcode:  210 of 225
# no results
# done postcode:  211 of 225
# no results
# done postcode:  212 of 225
# no results
# done postcode:  213 of 225
# no results
# done postcode:  214 of 225
# no results
# done postcode:  215 of 225
# no results
# done postcode:  216 of 225
# no results
# done postcode:  217 of 225
# no results
# done postcode:  218 of 225
# no results
# done postcode:  219 of 225
# no results
# done postcode:  220 of 225
# no results
# done postcode:  221 of 225
# no results
# done postcode:  222 of 225
# no results
# done postcode:  223 of 225
# no results
# done postcode:  224 of 225
# no results
# done postcode:  225 of 225
